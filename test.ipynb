# %%
import pandas as pd

base = r"data/pre_pam_variant_table_csv"

pam = pd.read_csv(f"{base}/PAM_Filtered_Only.csv")
pre = pd.read_csv(f"{base}/PrePAM_Only_Het_Common.csv")
combined = pd.read_csv(f"{base}/Targetable_and_Het_Var.csv")

print("PAM-filtered only:", len(pam), "rows,", pam["Gene"].nunique(), "genes")
print("Pre-PAM only:", len(pre), "rows,", pre["Gene"].nunique(), "genes")
print("Combined total:", len(combined), "rows,", combined["Gene"].nunique(), "genes")
# Out:
# PAM-filtered only: 1605 rows, 303 genes
# Pre-PAM only: 1854 rows, 328 genes
# Combined total: 3459 rows, 415 genes
